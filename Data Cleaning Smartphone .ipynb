# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('smartphones - smartphones.csv')

# %%
df
# Out:
#                                 model    price  rating
# 0                       OnePlus 11 5G  ₹54,999    89.0  \
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 11 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df1 = df.copy()

# %%
df1
# Out:
#                                 model    price  rating
# 0                       OnePlus 11 5G  ₹54,999    89.0  \
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 11 columns]

# %%
# Data Assessing
'''
Quality Issues
1.model - some brands are written diiferently like OPPO in model column consistency
2.price - has unneccesary '₹' validity
3.price - has ',' between numbers validity
4.price - phone Namotel has a price of 99 accuracy
5.ratings - missing values completeness
6.processor - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) validity
7.There is ipod on row 756 validity
8.memory - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) validity
9.battery - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) validity
10.display - sometimes frequency is not available completeness
11.display - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) validity
12.certain phones are foldable and the info is scattered validity
13.camera - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
14.camera - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ) validity
15.card - sometimes contains info about os and camera validity
16.os - sometimes contains info about bluetooth and fm radio validity
17.os - issue with rows (324,378) validity
18.os - sometimes contains os version name like lollipop consistency
19.missing values in camera, card and os completeness
20.datatype of price and rating is incorrect validity
#Tidiness Issues
sim - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
ram - can be split into 2 cols RAM and ROM
processor - can be split into processor name, cores and cpu speed.
battery - can be split into battery capacity, fast_charging_available
display - can be split into size, resolution_width, resolution_height and frequency
camera - can be split into front and rear camera
card - can be split into supported, extended_upto
'''
# Out:
# "\nQuality Issues\n1.model - some brands are written diiferently like OPPO in model column consistency\n2.price - has unneccesary '₹' validity\n3.price - has ',' between numbers validity\n4.price - phone Namotel has a price of 99 accuracy\n5.ratings - missing values completeness\n6.processor - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) validity\n7.There is ipod on row 756 validity\n8.memory - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) validity\n9.battery - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) validity\n10.display - sometimes frequency is not available completeness\n11.display - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) validity\n12.certain phones are foldable and the info is scattered validity\n13.camera - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'\n14.camera - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ) validity\n15.card - sometimes contains info about os and camera validity\n16.os - sometimes contains info about bluetooth and fm radio validity\n17.os - issue with rows (324,378) validity\n18.os - sometimes contains os version name like lollipop consistency\n19.missing values in camera, card and os completeness\n20.datatype of price and rating is incorrect validity\n#Tidiness Issues\nsim - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster\nram - can be split into 2 cols RAM and ROM\nprocessor - can be split into processor name, cores and cpu speed.\nbattery - can be split into battery capacity, fast_charging_available\ndisplay - can be split into size, resolution_width, resolution_height and frequency\ncamera - can be split into front and rear camera\ncard - can be split into supported, extended_upto\n"

# %%
#Replacing rupees symbol and comma so we can meke this column 
df1['price'] = df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df1 = df1.reset_index()

# %%
df1['index'] = df1['index'] + 2
#because we have done obsn in spredsheet and in spreadsheet the index starts from 2

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
#this will give the all problamitic rows
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating
# 98      100                     Vivo X Fold 5G  106990     NaN  \
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 988                                            Dual Sim
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1000                                           Dual Sim
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor  \
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# ...                                                ...
# 954      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 988                            8 MB RAM, 16 MB inbuilt
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
# 1000                                             No 3G
# 1014   Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram
# 98    12 GB RAM, 256 GB inbuilt  \
# 111     4 GB RAM, 64 GB inbuilt
# 149     4 GB RAM, 64 GB inbuilt
# 155    4 GB RAM, 512 MB inbuilt
# 159   12 GB RAM, 256 GB inbuilt
# ...                         ...
# 954   12 GB RAM, 512 GB inbuilt
# 988            1200 mAh Battery
# 993    8 GB RAM, 512 GB inbuilt
# 1000                    No Wifi
# 1014  12 GB RAM, 256 GB inbuilt
#
#                                                 battery
# 98              4600 mAh Battery with 66W Fast Charging  \
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                                    1450 mAh Battery
# 159             4520 mAh Battery with 67W Fast Charging
# ...                                                 ...
# 954             4600 mAh Battery with 66W Fast Charging
# 988                    2.4 inches, 240 x 320 px Display
# 993             4500 mAh Battery with 55W Fast Charging
# 1000                           32 MB RAM, 32 MB inbuilt
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display  \
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# ...                                                 ...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 988                                  0.3 MP Rear Camera
# 993                    8 inches, 2200 x 2480 px Display
# 1000                                    800 mAh Battery
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                  camera
# 98                     Foldable Display  \
# 111           Memory Card Not Supported
# 149           Memory Card Not Supported
# 155                        Dual Display
# 159      Foldable Display, Dual Display
# ...                                 ...
# 954                    Foldable Display
# 988   Memory Card Supported, upto 32 GB
# 993                    Foldable Display
# 1000  1.77 inches, 240 x 320 px Display
# 1014                   Foldable Display
#
#                                                    card
# 98                 50 MP Quad Rear & 16 MP Front Camera  \
# 111                                             iOS v14
# 149                                             iOS v14
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# ...                                                 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 988                                           Bluetooth
# 993                              48 MP Quad Rear Camera
# 1000                                       Dual Display
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# ...                                 ...
# 954                         Android v12
# 988                             Browser
# 993   Memory Card (Hybrid), upto 256 GB
# 1000                 1.3 MP Rear Camera
# 1014                        Android v12
#
# [68 rows x 12 columns]

# %%
#problem in all columns
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating
# 640     642          Nokia 105 Plus   1299     NaN  \
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt  \
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display  \
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB  \
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                     card                                 os
# 640            Bluetooth                                NaN
# 645            Bluetooth                                NaN
# 647                  NaN                                NaN
# 657            Bluetooth                                NaN
# 665            Bluetooth                                NaN
# 748              Browser                                NaN
# 757            Bluetooth                                NaN
# 817   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 882   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925            Bluetooth                            Browser
# 927                  NaN                                NaN
# 930            Bluetooth                            Browser
# 1000        Dual Display                 1.3 MP Rear Camera

# %%
#all the problamatic rows are mostly cheaper than 3000
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
#by seeing this dataset 3400 below doesnt consist of smart phone
df1 = df1[df1['price'] >= 3400]

# %%
df1
# Out:
#       index                            model  price  rating
# 0         2                    OnePlus 11 5G  54999    89.0  \
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [991 rows x 12 columns]

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating
# 645    647         Nokia 2760 Flip   5490     NaN  \
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery  \
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera  \
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0  \
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                                     model   price  rating
# 98      100                            Vivo X Fold 5G  106990     NaN  \
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 376     378                           Nokia 2660 Flip    4649     NaN
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 483     485          Huawei Mate 50 RS Porsche Design  239999    81.0
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 582     584                             Nokia 8210 4G    3749     NaN
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 645     647                           Nokia 2760 Flip    5490     NaN
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 754     756                Apple iPod Touch (7th Gen)   18900     NaN
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 856     858                   Samsung Galaxy A01 Core    4999     NaN
# 857     859                               LG Folder 2   11999     NaN
# 882     884                    Nokia 5710 XpressAudio    4799     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 925     927                             Nokia 3310 4G    3999     NaN
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 271                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                                    Dual Sim, 3G, 4G
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 582                                    Dual Sim, 3G, 4G
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 645                             Dual Sim, 3G, 4G, Wi-Fi
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 754                                               Wi-Fi
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 857                           Single Sim, 3G, 4G, Wi-Fi
# 882                                    Dual Sim, 3G, 4G
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 925                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor  \
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 155      Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 271       Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 376                                             No Wifi
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 483    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 582                                             No Wifi
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 645                                    1450 mAh Battery
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 754                                       32 GB inbuilt
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 857                              1 GB RAM, 8 GB inbuilt
# 882                                             No Wifi
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 925                          256 MB RAM, 512 MB inbuilt
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                                    ram
# 98           12 GB RAM, 256 GB inbuilt  \
# 111            4 GB RAM, 64 GB inbuilt
# 149            4 GB RAM, 64 GB inbuilt
# 155           4 GB RAM, 512 MB inbuilt
# 159          12 GB RAM, 256 GB inbuilt
# 236          12 GB RAM, 256 GB inbuilt
# 271           512 MB RAM, 4 GB inbuilt
# 306           8 GB RAM, 128 GB inbuilt
# 307           4 GB RAM, 128 GB inbuilt
# 321          12 GB RAM, 256 GB inbuilt
# 322           8 GB RAM, 128 GB inbuilt
# 363           4 GB RAM, 128 GB inbuilt
# 365           8 GB RAM, 128 GB inbuilt
# 376                        Unisoc T107
# 392           8 GB RAM, 256 GB inbuilt
# 439                      64 GB inbuilt
# 448           8 GB RAM, 128 GB inbuilt
# 482          12 GB RAM, 256 GB inbuilt
# 483                     512 GB inbuilt
# 504           8 GB RAM, 128 GB inbuilt
# 569          12 GB RAM, 256 GB inbuilt
# 570           8 GB RAM, 128 GB inbuilt
# 582                        Unisoc T107
# 613          12 GB RAM, 256 GB inbuilt
# 628           6 GB RAM, 512 GB inbuilt
# 645   3.6 inches, 240 x 320 px Display
# 682           8 GB RAM, 128 GB inbuilt
# 703           8 GB RAM, 256 GB inbuilt
# 709           8 GB RAM, 256 GB inbuilt
# 721          16 GB RAM, 512 GB inbuilt
# 726           8 GB RAM, 512 GB inbuilt
# 754    4 inches, 640 x 1136 px Display
# 762                      64 GB inbuilt
# 790          12 GB RAM, 256 GB inbuilt
# 844            2 GB RAM, 16 GB inbuilt
# 853           6 GB RAM, 256 GB inbuilt
# 856            1 GB RAM, 16 GB inbuilt
# 857                   1470 mAh Battery
# 882                        Unisoc T107
# 894           8 GB RAM, 128 GB inbuilt
# 913           4 GB RAM, 256 GB inbuilt
# 914           4 GB RAM, 256 GB inbuilt
# 925                   1200 mAh Battery
# 943            12 GB RAM, 1 TB inbuilt
# 954          12 GB RAM, 512 GB inbuilt
# 993           8 GB RAM, 512 GB inbuilt
# 1014         12 GB RAM, 256 GB inbuilt
#
#                                                 battery
# 98              4600 mAh Battery with 66W Fast Charging  \
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                                    1450 mAh Battery
# 159             4520 mAh Battery with 67W Fast Charging
# 236             4500 mAh Battery with 67W Fast Charging
# 271                                    1500 mAh Battery
# 306             3300 mAh Battery with 15W Fast Charging
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321             4400 mAh Battery with 25W Fast Charging
# 322                                    4450 mAh Battery
# 363                  5.4 inches, 1080 x 2340 px Display
# 365             4300 mAh Battery with 44W Fast Charging
# 376                           48 MB RAM, 128 MB inbuilt
# 392             4300 mAh Battery with 44W Fast Charging
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482             4730 mAh Battery with 80W Fast Charging
# 483             4700 mAh Battery with 66W Fast Charging
# 504             3700 mAh Battery with 25W Fast Charging
# 569             4400 mAh Battery with 25W Fast Charging
# 570                 4000 mAh Battery with Fast Charging
# 582                           48 MB RAM, 128 MB inbuilt
# 613             9800 mAh Battery with 66W Fast Charging
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 645                       5 MP Rear & 5 MP Front Camera
# 682                 5000 mAh Battery with Fast Charging
# 703             4500 mAh Battery with 33W Fast Charging
# 709             4000 mAh Battery with 45W Fast Charging
# 721             6000 mAh Battery with 65W Fast Charging
# 726             4600 mAh Battery with 66W Fast Charging
# 754                     8 MP Rear & 1.2 MP Front Camera
# 762                   6.1 inches, 750 x 1580 px Display
# 790             5020 mAh Battery with 67W Fast Charging
# 844                                    2000 mAh Battery
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 856                                    3000 mAh Battery
# 857                    2.8 inches, 240 x 320 px Display
# 882                           48 MB RAM, 128 MB inbuilt
# 894                                    3360 mAh Battery
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 925                    2.4 inches, 240 x 320 px Display
# 943             4400 mAh Battery with 25W Fast Charging
# 954             4600 mAh Battery with 66W Fast Charging
# 993             4500 mAh Battery with 55W Fast Charging
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display  \
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 271                    2.8 inches, 240 x 320 px Display
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 376                                    1450 mAh Battery
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 483         6.74 inches, 1212 x 2616 px, 120 Hz Display
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 582                                    1450 mAh Battery
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 645                   Memory Card Supported, upto 32 GB
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 754                                             iOS v12
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 856                   5.3 inches, 720 x 1480 px Display
# 857                                    2 MP Rear Camera
# 882                                    1450 mAh Battery
# 894                  7.2 inches, 1440 x 1920 px Display
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 925                                    2 MP Rear Camera
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera
# 98                                     Foldable Display  \
# 111                           Memory Card Not Supported
# 149                           Memory Card Not Supported
# 155                                        Dual Display
# 159                      Foldable Display, Dual Display
# 236                      Foldable Display, Dual Display
# 271                                        Dual Display
# 306                      Foldable Display, Dual Display
# 307                           Memory Card Not Supported
# 321                      Foldable Display, Dual Display
# 322                      Foldable Display, Dual Display
# 363                           Memory Card Not Supported
# 365                      Foldable Display, Dual Display
# 376                    2.8 inches, 240 x 320 px Display
# 392                      Foldable Display, Dual Display
# 439                           Memory Card Not Supported
# 448                           Memory Card Not Supported
# 482                      Foldable Display, Dual Display
# 483   50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 504                      Foldable Display, Dual Display
# 569                      Foldable Display, Dual Display
# 570                                        Dual Display
# 582                    2.8 inches, 240 x 320 px Display
# 613                                        Dual Display
# 628                           Memory Card Not Supported
# 645                                          Kaios v3.0
# 682                                        Dual Display
# 703                      Foldable Display, Dual Display
# 709                                        Dual Display
# 721                                        Dual Display
# 726                                    Foldable Display
# 754                                         No FM Radio
# 762                           Memory Card Not Supported
# 790                      Foldable Display, Dual Display
# 844                                        Dual Display
# 853                           Memory Card Not Supported
# 856                       8 MP Rear & 5 MP Front Camera
# 857                               Memory Card Supported
# 882                    2.4 inches, 240 x 320 px Display
# 894                      Foldable Display, Dual Display
# 913                           Memory Card Not Supported
# 914                           Memory Card Not Supported
# 925                   Memory Card Supported, upto 32 GB
# 943                      Foldable Display, Dual Display
# 954                                    Foldable Display
# 993                                    Foldable Display
# 1014                                   Foldable Display
#
#                                                    card
# 98                 50 MP Quad Rear & 16 MP Front Camera  \
# 111                                             iOS v14
# 149                                             iOS v14
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 271                                    2 MP Rear Camera
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                                             iOS v14
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                                             iOS v14
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 376                                        Dual Display
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                                             iOS v15
# 448                                             iOS v15
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 483                   Memory Card (Hybrid), upto 256 GB
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 582                                  0.3 MP Rear Camera
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                                           iOS v14.0
# 645                                           Bluetooth
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 754                                           Bluetooth
# 762                                             iOS v16
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853                                           iOS v14.0
# 856                               Memory Card Supported
# 857                                           Bluetooth
# 882                                  0.3 MP Rear Camera
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                                             iOS v14
# 914                                             iOS v14
# 925                                           Bluetooth
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                          No FM Radio
# 149                          No FM Radio
# 155    Memory Card Supported, upto 32 GB
# 159            Memory Card Not Supported
# 236                          Android v12
# 271                Memory Card Supported
# 306            Memory Card Not Supported
# 307                          No FM Radio
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                          No FM Radio
# 365            Memory Card Not Supported
# 376                   0.3 MP Rear Camera
# 392            Memory Card Not Supported
# 439                          No FM Radio
# 448                          No FM Radio
# 482                          Android v12
# 483                     Hongmeng OS v3.0
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 582    Memory Card Supported, upto 32 GB
# 613                 Memory Card (Hybrid)
# 628                          No FM Radio
# 645                                  NaN
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 754                              Browser
# 762                          No FM Radio
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 853                          No FM Radio
# 856                          Android v10
# 857                                  NaN
# 882    Memory Card Supported, upto 32 GB
# 894   Memory Card Supported, upto 256 GB
# 913                          No FM Radio
# 914                          No FM Radio
# 925                              Browser
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
df1
# Out:
#       index                            model  price  rating
# 0         2                    OnePlus 11 5G  54999    89.0  \
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [991 rows x 12 columns]

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating
# 645    647         Nokia 2760 Flip   5490     NaN  \
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery  \
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera  \
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0  \
# 857                   2 MP Rear Camera              Memory Card Supported
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 857           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
df1.drop([645,857,882,925],inplace=True)

# %%
df1
# Out:
#       index                            model  price  rating
# 0         2                    OnePlus 11 5G  54999    89.0  \
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [987 rows x 12 columns]

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating
# 439    441            Apple iPhone SE 3 2022   43900     NaN  \
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt  \
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery
# 439        4.7 inches, 750 x 1334 px Display  \
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
#                                          display
# 439               12 MP Rear & 7 MP Front Camera  \
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 582                             1450 mAh Battery
#
#                                                 camera
# 439                          Memory Card Not Supported  \
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 582                   2.8 inches, 240 x 320 px Display
#
#                                   card                                 os
# 439                            iOS v15                        No FM Radio
# 483  Memory Card (Hybrid), upto 256 GB                   Hongmeng OS v3.0
# 582                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB

# %%
df1.drop(582,inplace=True)

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating
# 111    113               Apple iPhone 12   51999    74.0  \
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                         Dual Sim, 3G, 4G
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 754                                    Wi-Fi
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor  \
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor
# 376                                     No Wifi
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                 Bionic  A16
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor
# 754                               32 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                                  ram
# 111          4 GB RAM, 64 GB inbuilt  \
# 149          4 GB RAM, 64 GB inbuilt
# 307         4 GB RAM, 128 GB inbuilt
# 363         4 GB RAM, 128 GB inbuilt
# 376                      Unisoc T107
# 439                    64 GB inbuilt
# 448         8 GB RAM, 128 GB inbuilt
# 628         6 GB RAM, 512 GB inbuilt
# 754  4 inches, 640 x 1136 px Display
# 762                    64 GB inbuilt
# 853         6 GB RAM, 256 GB inbuilt
# 913         4 GB RAM, 256 GB inbuilt
# 914         4 GB RAM, 256 GB inbuilt
#
#                                                battery
# 111  6.1 inches, 1170 x 2532 px Display with Large ...  \
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 376                          48 MB RAM, 128 MB inbuilt
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera  \
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 376                                   1450 mAh Battery
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                                camera          card                  os
# 111         Memory Card Not Supported       iOS v14         No FM Radio
# 149         Memory Card Not Supported       iOS v14         No FM Radio
# 307         Memory Card Not Supported       iOS v14         No FM Radio
# 363         Memory Card Not Supported       iOS v14         No FM Radio
# 376  2.8 inches, 240 x 320 px Display  Dual Display  0.3 MP Rear Camera
# 439         Memory Card Not Supported       iOS v15         No FM Radio
# 448         Memory Card Not Supported       iOS v15         No FM Radio
# 628         Memory Card Not Supported     iOS v14.0         No FM Radio
# 754                       No FM Radio     Bluetooth             Browser
# 762         Memory Card Not Supported       iOS v16         No FM Radio
# 853         Memory Card Not Supported     iOS v14.0         No FM Radio
# 913         Memory Card Not Supported       iOS v14         No FM Radio
# 914         Memory Card Not Supported       iOS v14         No FM Radio

# %%
df1.drop([376,754],inplace=True)

# %%
temp_df = df1[df1['index'].isin(battery_rows)]

# %%
#shifted by 1
x = temp_df.iloc[:,7:].shift(1,axis=1).values

# %% [markdown]
# temp_df.index

# %%
x_index = temp_df.index

# %%
df1.loc[x_index,temp_df.columns[7:]] = x

# %%
df1[df1['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating
# 439    441        Apple iPhone SE 3 2022   43900     NaN  \
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt  \
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#     battery                                            display
# 439    None                  4.7 inches, 750 x 1334 px Display  \
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera
# 439                     12 MP Rear & 7 MP Front Camera  \
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating
# 98      100                            Vivo X Fold 5G  106990     NaN  \
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 856     858                   Samsung Galaxy A01 Core    4999     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 271                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor  \
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 155      Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 271       Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                  battery
# 98    12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging  \
# 111     4 GB RAM, 64 GB inbuilt                                     None
# 149     4 GB RAM, 64 GB inbuilt                                     None
# 155    4 GB RAM, 512 MB inbuilt                         1450 mAh Battery
# 159   12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236   12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 271    512 MB RAM, 4 GB inbuilt                         1500 mAh Battery
# 306    8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 307    4 GB RAM, 128 GB inbuilt                                     None
# 321   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322    8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 363    4 GB RAM, 128 GB inbuilt                                     None
# 365    8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392    8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 439               64 GB inbuilt                                     None
# 448    8 GB RAM, 128 GB inbuilt                                     None
# 482   12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 504    8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 569   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 570    8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613   12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 628    6 GB RAM, 512 GB inbuilt                                     None
# 682    8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 703    8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 709    8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 721   16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726    8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 762               64 GB inbuilt                                     None
# 790   12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 844     2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 853    6 GB RAM, 256 GB inbuilt                                     None
# 856     1 GB RAM, 16 GB inbuilt                         3000 mAh Battery
# 894    8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 913    4 GB RAM, 256 GB inbuilt                                     None
# 914    4 GB RAM, 256 GB inbuilt                                     None
# 943     12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 954   12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993    8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                 display
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display  \
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 271                    2.8 inches, 240 x 320 px Display
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363                  5.4 inches, 1080 x 2340 px Display
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 762                   6.1 inches, 750 x 1580 px Display
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 856                   5.3 inches, 720 x 1480 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera
# 98                                     Foldable Display  \
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                                        Dual Display
# 159                      Foldable Display, Dual Display
# 236                      Foldable Display, Dual Display
# 271                                        Dual Display
# 306                      Foldable Display, Dual Display
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321                      Foldable Display, Dual Display
# 322                      Foldable Display, Dual Display
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365                      Foldable Display, Dual Display
# 392                      Foldable Display, Dual Display
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482                      Foldable Display, Dual Display
# 504                      Foldable Display, Dual Display
# 569                      Foldable Display, Dual Display
# 570                                        Dual Display
# 613                                        Dual Display
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 682                                        Dual Display
# 703                      Foldable Display, Dual Display
# 709                                        Dual Display
# 721                                        Dual Display
# 726                                    Foldable Display
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790                      Foldable Display, Dual Display
# 844                                        Dual Display
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 856                       8 MP Rear & 5 MP Front Camera
# 894                      Foldable Display, Dual Display
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 943                      Foldable Display, Dual Display
# 954                                    Foldable Display
# 993                                    Foldable Display
# 1014                                   Foldable Display
#
#                                                    card
# 98                 50 MP Quad Rear & 16 MP Front Camera  \
# 111                           Memory Card Not Supported
# 149                           Memory Card Not Supported
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 271                                    2 MP Rear Camera
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                           Memory Card Not Supported
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                           Memory Card Not Supported
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                           Memory Card Not Supported
# 448                           Memory Card Not Supported
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                           Memory Card Not Supported
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                           Memory Card Not Supported
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853                           Memory Card Not Supported
# 856                               Memory Card Supported
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                           Memory Card Not Supported
# 914                           Memory Card Not Supported
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                              iOS v14
# 149                              iOS v14
# 155    Memory Card Supported, upto 32 GB
# 159            Memory Card Not Supported
# 236                          Android v12
# 271                Memory Card Supported
# 306            Memory Card Not Supported
# 307                              iOS v14
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                              iOS v14
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 439                              iOS v15
# 448                              iOS v15
# 482                          Android v12
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 613                 Memory Card (Hybrid)
# 628                            iOS v14.0
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 762                              iOS v16
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 853                            iOS v14.0
# 856                          Android v10
# 894   Memory Card Supported, upto 256 GB
# 913                              iOS v14
# 914                              iOS v14
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
#removing feature phone
#155 271
df1.drop([155,271],inplace=True)

# %%
temp_df = df1[df1['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]

# %%
df1.loc[temp_df.index,'camera'] = temp_df['card'].values

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating
# 98      100                            Vivo X Fold 5G  106990     NaN  \
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 856     858                   Samsung Galaxy A01 Core    4999     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor  \
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                  battery
# 98    12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging  \
# 111     4 GB RAM, 64 GB inbuilt                                     None
# 149     4 GB RAM, 64 GB inbuilt                                     None
# 159   12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236   12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 306    8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 307    4 GB RAM, 128 GB inbuilt                                     None
# 321   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322    8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 363    4 GB RAM, 128 GB inbuilt                                     None
# 365    8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392    8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 439               64 GB inbuilt                                     None
# 448    8 GB RAM, 128 GB inbuilt                                     None
# 482   12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 504    8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 569   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 570    8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613   12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 628    6 GB RAM, 512 GB inbuilt                                     None
# 682    8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 703    8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 709    8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 721   16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726    8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 762               64 GB inbuilt                                     None
# 790   12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 844     2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 853    6 GB RAM, 256 GB inbuilt                                     None
# 856     1 GB RAM, 16 GB inbuilt                         3000 mAh Battery
# 894    8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 913    4 GB RAM, 256 GB inbuilt                                     None
# 914    4 GB RAM, 256 GB inbuilt                                     None
# 943     12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 954   12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993    8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                 display
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display  \
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363                  5.4 inches, 1080 x 2340 px Display
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 762                   6.1 inches, 750 x 1580 px Display
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 856                   5.3 inches, 720 x 1480 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera
# 98                 50 MP Quad Rear & 16 MP Front Camera  \
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 856                       8 MP Rear & 5 MP Front Camera
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                                    card
# 98                 50 MP Quad Rear & 16 MP Front Camera  \
# 111                           Memory Card Not Supported
# 149                           Memory Card Not Supported
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                           Memory Card Not Supported
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                           Memory Card Not Supported
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                           Memory Card Not Supported
# 448                           Memory Card Not Supported
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                           Memory Card Not Supported
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                           Memory Card Not Supported
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853                           Memory Card Not Supported
# 856                               Memory Card Supported
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                           Memory Card Not Supported
# 914                           Memory Card Not Supported
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                              iOS v14
# 149                              iOS v14
# 159            Memory Card Not Supported
# 236                          Android v12
# 306            Memory Card Not Supported
# 307                              iOS v14
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                              iOS v14
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 439                              iOS v15
# 448                              iOS v15
# 482                          Android v12
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 613                 Memory Card (Hybrid)
# 628                            iOS v14.0
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 762                              iOS v16
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 853                            iOS v14.0
# 856                          Android v10
# 894   Memory Card Supported, upto 256 GB
# 913                              iOS v14
# 914                              iOS v14
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# Memory Card (Hybrid), upto 512 GB                                       11
# Memory Card Supported, upto 128 GB                                       6
# Memory Card Supported, upto 2 TB                                         5
# Memory Card Supported, upto 32 GB                                        4
# Memory Card (Hybrid), upto 64 GB                                         3
# Memory Card (Hybrid), upto 128 GB                                        3
# Android v9.0 (Pie)                                                       2
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       2
# 64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera                    2
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                              2
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                             2
# 50 MP Quad Rear & 16 MP Front Camera                                     2
# 64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera                  1
# 48 MP Quad Rear Camera                                                   1
# HarmonyOS                                                                1
# Memory Card (Hybrid), upto 2 TB                                          1
# 5 MP Rear & 2 MP Front Camera                                            1
# 108 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                   1
# HarmonyOS v2.0                                                           1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                  1
# 50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera                    1
# 64 MP + 16 MP + 12 MP Triple Rear & 16 MP Front Camera                   1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                   1
# iOS v13                                                                  1
# 50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                    1
# Android v10.0                                                            1
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                     1
# iOS v10                                                                  1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                   1
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       1
# Memory Card Supported, upto 1000 GB                                      1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                        1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                    1
# Android v12.1                                                            1
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera      1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                   1
# Name: count, dtype: int64

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# Memory Card (Hybrid), upto 512 GB                                       11
# Memory Card Supported, upto 128 GB                                       6
# Memory Card Supported, upto 2 TB                                         5
# Memory Card Supported, upto 32 GB                                        4
# Memory Card (Hybrid), upto 64 GB                                         3
# Memory Card (Hybrid), upto 128 GB                                        3
# Android v9.0 (Pie)                                                       2
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       2
# 64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera                    2
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                              2
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                             2
# 50 MP Quad Rear & 16 MP Front Camera                                     2
# 64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera                  1
# 48 MP Quad Rear Camera                                                   1
# HarmonyOS                                                                1
# Memory Card (Hybrid), upto 2 TB                                          1
# 5 MP Rear & 2 MP Front Camera                                            1
# 108 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                   1
# HarmonyOS v2.0                                                           1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                  1
# 50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera                    1
# 64 MP + 16 MP + 12 MP Triple Rear & 16 MP Front Camera                   1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                   1
# iOS v13                                                                  1
# 50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                    1
# Android v10.0                                                            1
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                     1
# iOS v10                                                                  1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                   1
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       1
# Memory Card Supported, upto 1000 GB                                      1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                        1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                    1
# Android v12.1                                                            1
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera      1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                   1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['card'].str.contains('MP')]

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              149
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# Android v10.0                            1
# iOS v13                                  1
# HarmonyOS v2.0                           1
# Memory Card (Hybrid), upto 2 TB          1
# HarmonyOS                                1
# Name: count, dtype: int64

# %%
temp_df =  df1[~df1['card'].str.contains('Memory Card')]

# %%
df1.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# EMUI v12                                2
# Memory Card Supported, upto 256 GB      2
# Android v12.1                           2
# iOS v14.0                               2
# Memory Card Supported, upto 128 GB      1
# Android v7.1 (Nougat)                   1
# Android                                 1
# Hongmeng OS v4.0                        1
# HarmonyOS                               1
# Android v5.1 (Lollipop)                 1
# RTOS (Series 30+)                       1
# Memory Card (Hybrid)                    1
# iOS v10                                 1
# Pragati OS (Powered by Android)         1
# Bluetooth                               1
# Hongmeng OS v3.0                        1
# Android v4.4.2 (KitKat)                 1
# iOS v17                                 1
# iOS v12.3                               1
# iOS v13.0                               1
# HarmonyOS v2                            1
# Android v9 (Pie)                        1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]

# %%
temp_df
# Out:
#      index                       model   price  rating
# 159    161             Oppo Find N2 5G   94990     NaN  \
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 844                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  \
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging  \
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 844    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...  \
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 721        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 844                     4 inches, 480 x 640 px Display
# 894                 7.2 inches, 1440 x 1920 px Display
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...  \
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 721  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 993                             48 MP Quad Rear Camera
#
#                           card                                  os
# 159  Memory Card Not Supported           Memory Card Not Supported
# 306  Memory Card Not Supported           Memory Card Not Supported
# 322  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 365  Memory Card Not Supported           Memory Card Not Supported
# 392  Memory Card Not Supported           Memory Card Not Supported
# 504  Memory Card Not Supported           Memory Card Not Supported
# 570  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 613  Memory Card Not Supported                Memory Card (Hybrid)
# 682  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 721  Memory Card Not Supported           Memory Card Not Supported
# 726  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 844  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 894  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 993  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB

# %%
df1.loc[temp_df.index,'card'] = np.nan

# %%
temp_df = temp_df[temp_df['os'].str.contains('Memory Card')]

# %%
data = df1.copy()

# %%
df1['card'].unique()
# Out:
# array(['Memory Card Not Supported',
#        'Memory Card (Hybrid), upto 1\u2009TB',
#        'Memory Card Supported, upto 1\u2009TB', 'Memory Card Supported',
#        'Memory Card (Hybrid)', 'Memory Card Supported, upto 512\u2009GB',
#        'Memory Card Supported, upto 256\u2009GB',
#        'Memory Card Supported, upto 2\u2009TB',
#        'Memory Card Supported, upto 128\u2009GB', nan,
#        'Memory Card (Hybrid), upto 256\u2009GB',
#        'Memory Card (Hybrid), upto 128\u2009GB',
#        'Memory Card (Hybrid), upto 512\u2009GB',
#        'Memory Card Supported, upto 32\u2009GB',
#        'Memory Card (Hybrid), upto 64\u2009GB',
#        'Memory Card Supported, upto 1000\u2009GB',
#        'Memory Card (Hybrid), upto 2\u2009TB'], dtype=object)

# %%
df2['card'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15980\1427147579.py in <module>
# ----> 1 df2['card'].unique()
#
# NameError: name 'df2' is not defined

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]

# %%
temp_df
# Out:
#      index                       model   price  rating
# 159    161             Oppo Find N2 5G   94990     NaN  \
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 844                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  \
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging  \
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 844    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...  \
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 721        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 844                     4 inches, 480 x 640 px Display
# 894                 7.2 inches, 1440 x 1920 px Display
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...  \
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 721  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 993                             48 MP Quad Rear Camera
#
#                           card                                  os
# 159  Memory Card Not Supported           Memory Card Not Supported
# 306  Memory Card Not Supported           Memory Card Not Supported
# 322  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 365  Memory Card Not Supported           Memory Card Not Supported
# 392  Memory Card Not Supported           Memory Card Not Supported
# 504  Memory Card Not Supported           Memory Card Not Supported
# 570  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 613  Memory Card Not Supported                Memory Card (Hybrid)
# 682  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 721  Memory Card Not Supported           Memory Card Not Supported
# 726  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 844  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 894  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 993  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

# %%
temp = swap_columns(temp_df, 'card', 'os')

# %%
temp.rename(columns = {'os':'card','card':'os'}, inplace = True)

# %%
temp
# Out:
#      index                       model   price  rating
# 159    161             Oppo Find N2 5G   94990     NaN  \
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 844                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  \
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging  \
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 844    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...  \
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 721        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 844                     4 inches, 480 x 640 px Display
# 894                 7.2 inches, 1440 x 1920 px Display
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...  \
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 721  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 993                             48 MP Quad Rear Camera
#
#                                    card                         os
# 159           Memory Card Not Supported  Memory Card Not Supported
# 306           Memory Card Not Supported  Memory Card Not Supported
# 322  Memory Card Supported, upto 256 GB  Memory Card Not Supported
# 365           Memory Card Not Supported  Memory Card Not Supported
# 392           Memory Card Not Supported  Memory Card Not Supported
# 504           Memory Card Not Supported  Memory Card Not Supported
# 570     Memory Card (Hybrid), upto 2 TB  Memory Card Not Supported
# 613                Memory Card (Hybrid)  Memory Card Not Supported
# 682     Memory Card (Hybrid), upto 2 TB  Memory Card Not Supported
# 721           Memory Card Not Supported  Memory Card Not Supported
# 726   Memory Card (Hybrid), upto 256 GB  Memory Card Not Supported
# 844  Memory Card Supported, upto 128 GB  Memory Card Not Supported
# 894  Memory Card Supported, upto 256 GB  Memory Card Not Supported
# 993   Memory Card (Hybrid), upto 256 GB  Memory Card Not Supported

# %%
df1.loc[x_index,temp.columns[10:]] = x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15980\2024281452.py in <module>
# ----> 1 df1.loc[x_index,temp.columns[10:]] = x
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849         iloc._setitem_with_indexer(indexer, value, self.name)
#     850
#     851     def _validate_key(self, key, axis: AxisInt):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1826         if take_split_path:
#    1827             # We have to operate column-wise
# -> 1828             self._setitem_with_indexer_split_path(indexer, value, name)
#    1829         else:
#    1830             self._setitem_single_block(indexer, value, name)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1866                 # TODO: avoid np.ndim call in case it isn't an ndarray, since
#    1867                 #  that will construct an ndarray, which will be wasteful
# -> 1868                 self._setitem_with_indexer_2d_value(indexer, value)
#    1869
#    1870             elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_2d_value(self, indexer, value)
#    1932             value = np.array(value, dtype=object)
#    1933         if len(ilocs) != value.shape[1]:
# -> 1934             raise ValueError(
#    1935                 "Must have equal len keys and value when setting with an ndarray"
#    1936             )
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %%
x = temp[['card','os']].values

# %%
x
# Out:
# array([['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card Supported, upto 256\u2009GB',
#         'Memory Card Not Supported'],
#        ['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card (Hybrid), upto 2\u2009TB',
#         'Memory Card Not Supported'],
#        ['Memory Card (Hybrid)', 'Memory Card Not Supported'],
#        ['Memory Card (Hybrid), upto 2\u2009TB',
#         'Memory Card Not Supported'],
#        ['Memory Card Not Supported', 'Memory Card Not Supported'],
#        ['Memory Card (Hybrid), upto 256\u2009GB',
#         'Memory Card Not Supported'],
#        ['Memory Card Supported, upto 128\u2009GB',
#         'Memory Card Not Supported'],
#        ['Memory Card Supported, upto 256\u2009GB',
#         'Memory Card Not Supported'],
#        ['Memory Card (Hybrid), upto 256\u2009GB',
#         'Memory Card Not Supported']], dtype=object)

# %%
x_index = temp.index

# %%
x_index
# Out:
# Index([159, 306, 322, 365, 392, 504, 570, 613, 682, 721, 726, 844, 894, 993], dtype='int64')

# %%
df1[df1['card'].str.contains('Memory Card')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15980\69907310.py in <module>
# ----> 1 df1[df1['card'].str.contains('Memory Card')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3748
#    3749         # Do we have a (boolean) 1d indexer?
# -> 3750         if com.is_bool_indexer(key):
#    3751             return self._getitem_bool_array(key)
#    3752
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                     # Don't raise on e.g. ["A", "B", np.nan], see
#     133                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df1.iloc[159,0]
# Out:
# 162

# %%
temp_df = df1[df1['os'] == 'Bluetooth']

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# EMUI v12                                2
# Memory Card Supported, upto 256 GB      2
# Android v12.1                           2
# iOS v14.0                               2
# Memory Card Supported, upto 128 GB      1
# Android v7.1 (Nougat)                   1
# Android                                 1
# Hongmeng OS v4.0                        1
# HarmonyOS                               1
# Android v5.1 (Lollipop)                 1
# RTOS (Series 30+)                       1
# Memory Card (Hybrid)                    1
# iOS v10                                 1
# Pragati OS (Powered by Android)         1
# Bluetooth                               1
# Hongmeng OS v3.0                        1
# Android v4.4.2 (KitKat)                 1
# iOS v17                                 1
# iOS v12.3                               1
# iOS v13.0                               1
# HarmonyOS v2                            1
# Android v9 (Pie)                        1
# Name: count, dtype: int64

# %%
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               317
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                54
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim, 3G, 4G, Wi-Fi                                        7
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# Dual Sim, 3G, 4G, Wi-Fi, NFC                                   2
# Single Sim, 3G, 4G, Wi-Fi, NFC                                 1
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           1
# Dual Sim, 3G, 4G, VoLTE                                        1
# Dual Sim, 3G, Wi-Fi                                            1
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           1
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster      1
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    index                      model  price  rating
# 0      2              OnePlus 11 5G  54999    89.0  \
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
# 3      5       Motorola Moto G62 5G  14999    81.0
# 4      6         Realme 10 Pro Plus  24999    82.0
#
#                                        sim
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
brand_name = df1['model'].str.split(' ').str.get(0)

# %%
#creating new col in 2 position
df1.insert(1,'brand_name',brand_name)

# %%
df1
# Out:
#       index brand_name                            model  price  rating
# 0         2    OnePlus                    OnePlus 11 5G  54999    89.0  \
# 1         3    OnePlus        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4    Samsung            Samsung Galaxy A14 5G  16499    75.0
# 3         5   Motorola             Motorola Moto G62 5G  14999    81.0
# 4         6     Realme               Realme 10 Pro Plus  24999    82.0
# ...     ...        ...                              ...    ...     ...
# 1015   1017   Motorola       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018      Honor                      Honor X8 5G  14990    75.0
# 1017   1019       POCO  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020   Motorola             Motorola Moto G91 5G  19990    80.0
# 1019   1021    Samsung           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  \
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging  \
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015         Memory Card Not Supported  Android v12
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [982 rows x 13 columns]

# %%
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
has5G = df1['sim'].str.contains('5G')
hasnfc = df1['sim'].str.contains('NFC')
hasIrblasster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6,'has_5G',has5G)
df1.insert(7,'has_nfc',hasnfc)
df1.insert(6,'has_ir_blaster',hasIrblasster)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

# %%
num_cores = df1['processor'].str.split(',').str.get(1)

# %%
pro_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1.insert(10,'processor_name',processor_name)
df1.insert(11,'num_cores',num_cores)
df1.insert(12,'processor_speed',pro_speed)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor     processor_name
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#     num_cores     processor_speed                        ram
# 0   Octa Core   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2   Octa Core   2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4   Octa Core   2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 700 5G      29
# Helio P35             28
# Snapdragon 8+ Gen1    26
# Snapdragon 8 Gen2     23
# Snapdragon 695        23
#                       ..
# Tiger T606             1
# Snapdragon 615         1
# Helio MT6580           1
# Helio  G95             1
# Google  Tensor 3       1
# Name: count, Length: 246, dtype: int64

# %%
#used to see all rows
pd.set_option('display.max_rows', None)

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name','num_cores','processor_speed']].shift(1,axis=1)

# %%
df1.loc[temp_df.index,['processor_name','num_cores','processor_speed']] = temp_df.values

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Helio P35                  30
# Snapdragon 695             29
# Dimensity 700 5G           29
# Snapdragon 8+ Gen1         26
# Snapdragon  695            24
# Snapdragon 680             24
# Snapdragon 8 Gen2          23
# Helio G35                  20
# Snapdragon  680            19
# Snapdragon  8 Gen1         18
# Snapdragon 8 Gen1          18
# Snapdragon 870             16
# Bionic A15                 16
# Dimensity  810 5G          15
# Helio G96                  15
# Helio G99                  14
# Helio G80                  14
# Snapdragon  8+ Gen1        13
# Dimensity 810 5G           12
# Snapdragon 778G            12
# Dimensity 1080             12
# Snapdragon  888            12
# Helio G37                  11
# Snapdragon 888             11
# Dimensity  920 5G          11
# Helio  G85                 10
# Helio G25                  10
# Bionic  A16                10
# Helio A22                  10
# Helio G95                  10
# Tiger T612                  9
# Snapdragon 720G             9
# Snapdragon  778G            9
# Snapdragon 865              9
# Bionic A14                  8
# Helio G88                   8
# Helio G85                   8
# Dimensity 1300              8
# Dimensity 700               7
# Snapdragon  870             7
# Dimensity 8100 Max          6
# Dimensity 800U              6
# Unisoc  T606                6
# Snapdragon  7 Gen1          6
# Helio P22                   6
# Exynos 850                  6
# Snapdragon 765G             6
# Helio  G96                  6
# Dimensity 9000 Plus         6
# Dimensity 900               5
# Unisoc  SC9863A             5
# Snapdragon  732G            5
# Dimensity  8100             5
# Dimensity 1200              5
# Exynos  2100                5
# A13 Bionic                  5
# Dimensity 8200              5
# Snapdragon 778G Plus        5
# Exynos 1330                 4
# Snapdragon 4 Gen 1          4
# Dimensity 9000              4
# Exynos 990                  4
# Snapdragon  480             4
# Snapdragon  750G            4
# Exynos  1280                4
# Dimensity 720               4
# Snapdragon 888+             4
# Snapdragon 778G+            4
# Snapdragon  865             4
# Google  Tensor              4
# Exynos 1280                 4
# Tiger T610                  3
# Exynos 9825                 3
# Exynos  850                 3
# Snapdragon 732G             3
# Dimensity  930              3
# Snapdragon  8 Gen2          3
# Dimensity  900              3
# Qualcomm 215                3
# Snapdragon  665             3
# Snapdragon  720G            3
# Dimensity  1300             3
# Snapdragon  765G            3
# Exynos  990                 3
# Snapdragon 439              3
# Snapdragon 845              3
# Snapdragon 662              3
# Snapdragon  888+            3
# Dimensity 810               3
# Dimensity  700 5G           3
# Snapdragon 460              3
# Dimensity 9200              3
# Tiger  T616                 3
# Snapdragon 7 Gen1           3
# Helio P60                   3
# Snapdragon 480+             3
# Helio  G25                  3
# Helio  G99                  3
# Dimensity 8100-Max          3
# Snapdragon 678              2
# Snapdragon  4 Gen 1         2
# Dimensity  9000             2
# Snapdragon 855+             2
# Snapdragon  778G Plus       2
# Tiger  T310                 2
# Helio P70                   2
# Bionic  A15                 2
# Snapdragon  439             2
# Kirin  990                  2
# Tiger T616                  2
# Snapdragon 425              2
# Snapdragon 690              2
# Snapdragon  675             2
# Snapdragon 6 Gen 1          2
# Unisoc  T610                2
# Unisoc  SC9863a             2
# Exynos 9810                 2
# Exynos 9611                 2
# Dimensity 8100              2
# Helio P95                   2
# Dimensity  8200             2
# Helio                       2
# Unisoc T612                 2
# Snapdragon  480+            2
# SC9863A                     2
# Helio  P22                  2
# Bionic A16                  2
# Helio G70                   2
# Dimensity  900 5G           2
# Unisoc SC9863A              2
# Spreadtrum  SC9832E         2
# Dimensity 920 5G            2
# Exynos 9820                 2
# Snapdragon 712              2
# Snapdragon 665              1
# Exynos 7885                 1
# Helio P23                   1
# Exynos  9611                1
# Snapdragon  712             1
# Unisoc SC7731E              1
# Dimensity 1000+             1
# Dimensity 8100 Ultra        1
# Spreadtrum  SC7731          1
# Snapdragon  782G            1
# Helio A25                   1
# Snapdragon MSM8939          1
# Kirin 9000E                 1
# Kirin 659                   1
# Google Tensor 3             1
# Snapdragon  730G            1
# Helio   G90T                1
# Samsung Exynos 7885         1
# Qualcomm Snapdragon 670     1
# Snapdragon  7 Gen2          1
# Helio  P65                  1
# Helio  G88                  1
# Kirin  810                  1
# Snapdragon  855             1
# (28 nm)                     1
# Snapdragon  778G+           1
# Unisoc  A55                 1
# Snapdragon 450              1
# Snapdragon 675              1
# Snapdragon 710              1
# Kirin 990                   1
# Exynos 2100                 1
# Snapdragon  662             1
# Snapdragon  690             1
# Qualcomm Snapdragon 625     1
# Helio  G90T                 1
# Helio  G37                  1
# Exynos 7904                 1
# Snapdragon 730G             1
# Bionic  A17                 1
# Spreadtrum  SC7731E         1
# Unisoc                      1
# Snapdragon 730              1
# Snapdragon 855              1
# Snapdragon 8+ Gen 2         1
# Unisoc  SC9836A             1
# Google Tensor               1
# Dimensity  1200 Max         1
# Apple  A13                  1
# Exynos  2300                1
# Dimensity 930               1
# Google Tensor G2            1
# Google  Tensor G2           1
# Exynos 1380                 1
# Tiger T7150                 1
# Tiger T310                  1
# Exynos 1200                 1
# Tiger T700                  1
# Snapdragon  810             1
# Snapdragon 775              1
# Snapdragon 801              1
# Snapdragon 835              1
# Dimensity 1100 5G           1
# Tiger  T610                 1
# Snapdragon  6 Gen 1         1
# Dimensity  9200             1
# Kirin  9000                 1
# Unisoc T117                 1
# Unisoc T610                 1
# Fusion APL1024              1
# Sanpdragon 680              1
# Snapdragon 860              1
# Snapdragon  210             1
# Unisoc  SC9832E             1
# Tiger T606                  1
# Snapdragon 615              1
# Helio MT6580                1
# Helio  G95                  1
# Unisoc T606                 1
# Helio  P35                  1
# Google  Tensor 3            1
# Name: count, dtype: int64

# %%
df1.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
df1.loc[856]
# Out:
# index                                                858
# brand_name                                       samsung
# model                            Samsung Galaxy A01 Core
# price                                               4999
# rating                                               NaN
# sim                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_ir_blaster                                     False
# has_5G                                             False
# has_nfc                                            False
# processor          (28 nm), Quad Core, 1.5 GHz Processor
# processor_name                           Mediatek MT6739
# num_cores                                      Quad Core
# processor_speed                        1.5 GHz Processor
# ram                              1 GB RAM, 16 GB inbuilt
# battery                                 3000 mAh Battery
# display                5.3 inches, 720 x 1480 px Display
# camera                     8 MP Rear & 5 MP Front Camera
# card                               Memory Card Supported
# os                                           Android v10
# Name: 856, dtype: object

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor     processor_name
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand   num_cores     processor_speed                        ram
# 0      snapdragon   Octa Core   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1      snapdragon   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2          exynos   Octa Core   2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3      snapdragon   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4       dimensity   Octa Core   2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core').value_counts()

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor     processor_name
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores     processor_speed                        ram
# 0      snapdragon        NaN   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt  \
# 1      snapdragon        NaN   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2          exynos        NaN   2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3      snapdragon        NaN   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4       dimensity        NaN   2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor     processor_name
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram
# 0      snapdragon        NaN              3.2  12 GB RAM, 256 GB inbuilt  \
# 1      snapdragon        NaN              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos        NaN              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon        NaN              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity        NaN              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery
# 0  5000 mAh Battery with 100W Fast Charging  \
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(16,'ram_capacity',ram_capacity)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor  ... processor_brand
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...      snapdragon  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...      snapdragon
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...          exynos
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...      snapdragon
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...       dimensity
#
#   num_cores  processor_speed                        ram
# 0       NaN              3.2  12 GB RAM, 256 GB inbuilt  \
# 1       NaN              2.2   6 GB RAM, 128 GB inbuilt
# 2       NaN              2.4    4 GB RAM, 64 GB inbuilt
# 3       NaN              2.2   6 GB RAM, 128 GB inbuilt
# 4       NaN              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery ram_capacity
# 0  5000 mAh Battery with 100W Fast Charging           12  \
# 1   5000 mAh Battery with 33W Fast Charging            6
# 2   5000 mAh Battery with 15W Fast Charging            4
# 3       5000 mAh Battery with Fast Charging            6
# 4   5000 mAh Battery with 67W Fast Charging            6
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13
#
# [5 rows x 21 columns]

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(14,'internal_memory',internal_memory)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor  ... num_cores
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...       NaN  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...       NaN
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...       NaN
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...       NaN
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...       NaN
#
#   processor_speed  internal_memory                        ram
# 0             3.2              256  12 GB RAM, 256 GB inbuilt  \
# 1             2.2              128   6 GB RAM, 128 GB inbuilt
# 2             2.4               64    4 GB RAM, 64 GB inbuilt
# 3             2.2              128   6 GB RAM, 128 GB inbuilt
# 4             2.6              128   6 GB RAM, 128 GB inbuilt
#
#                                     battery ram_capacity
# 0  5000 mAh Battery with 100W Fast Charging           12  \
# 1   5000 mAh Battery with 33W Fast Charging            6
# 2   5000 mAh Battery with 15W Fast Charging            4
# 3       5000 mAh Battery with Fast Charging            6
# 4   5000 mAh Battery with 67W Fast Charging            6
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13
#
# [5 rows x 22 columns]

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name          model  price  rating                      sim
# 486    488      nokia  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi  \
# 627    629      nokia   Nokia 225 4G   3589     NaN  Dual Sim, 3G, 4G, VoLTE
#
#      has_ir_blaster  has_5G  has_nfc
# 486           False   False    False  \
# 627           False   False    False
#
#                                          processor  ... processor_speed
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  ...             1.1  \
# 627                                    Unisoc T117  ...             NaN
#
#     internal_memory                        ram           battery ram_capacity
# 486               4   512 MB RAM, 4 GB inbuilt  1500 mAh Battery        512.0  \
# 627             128  64 MB RAM, 128 MB inbuilt  1150 mAh Battery         64.0
#
#                               display              camera
# 486  2.8 inches, 240 x 320 px Display    2 MP Rear Camera  \
# 627  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
#
#                                   card                 os ram memory
# 486              Memory Card Supported                NaN        NaN
# 627  Memory Card Supported, upto 32 GB  RTOS (Series 30+)        NaN
#
# [2 rows x 23 columns]

# %%
df1.loc[[483],['ram_capacity','internal_memory']] = [12.0,'512']

# %%
df1.drop([486,627],inplace=True)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0     339
# 6.0     234
# 4.0     217
# 12.0     86
# 3.0      54
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# Name: count, dtype: int64

# %%
df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1[df1['internal_memory'] == 1]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_ir_blaster, has_5G, has_nfc, processor, processor_name, processor_brand, num_cores, processor_speed, internal_memory, ram, battery, ram_capacity, display, camera, card, os, ram memory]
# Index: []
#
# [0 rows x 23 columns]

# %%
df1.loc[temp_df.index,'internal_memory'] = 1024

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       67
# 512.0      22
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: count, dtype: int64

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

# %%
df1.insert(16,'battery_capacity',battery_capacity)

# %%
df1.drop('battery_capacity', axis=1,inplace=True)

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# [33]     152
# [18]     128
# []        68
# [67]      65
# [25]      53
# [120]     46
# [15]      43
# [80]      42
# [66]      37
# [10]      33
# [30]      32
# [65]      30
# [44]      23
# [45]      17
# [20]      10
# [68]       8
# [100]      7
# [150]      7
# [125]      6
# [40]       5
# [22]       5
# [60]       4
# [55]       3
# [50]       2
# [210]      2
# [21]       2
# [180]      1
# [200]      1
# [240]      1
# [19]       1
# [135]      1
# [165]      1
# [27]       1
# Name: count, dtype: int64

# %%
def fast_charging_extract(item):
    if type(item) == list:
        if len(item) == 1:
            return item[0]
        else:
            return 0
    else:
        return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extract).astype(int)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor  ...
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...
#
#                          ram battery_capacity  fast_charging
# 0  12 GB RAM, 256 GB inbuilt           5000.0            100  \
# 1   6 GB RAM, 128 GB inbuilt           5000.0             33
# 2    4 GB RAM, 64 GB inbuilt           5000.0             15
# 3   6 GB RAM, 128 GB inbuilt           5000.0              0
# 4   6 GB RAM, 128 GB inbuilt           5000.0             67
#
#                                     battery  ram_capacity
# 0  5000 mAh Battery with 100W Fast Charging          12.0  \
# 1   5000 mAh Battery with 33W Fast Charging           6.0
# 2   5000 mAh Battery with 15W Fast Charging           4.0
# 3       5000 mAh Battery with Fast Charging           6.0
# 4   5000 mAh Battery with 67W Fast Charging           6.0
#
#                                              display
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os  ram memory
# 0         Memory Card Not Supported  Android v13         NaN
# 1   Memory Card (Hybrid), upto 1 TB  Android v12         NaN
# 2  Memory Card Supported, upto 1 TB  Android v13         NaN
# 3   Memory Card (Hybrid), upto 1 TB  Android v12         NaN
# 4         Memory Card Not Supported  Android v13         NaN
#
# [5 rows x 25 columns]

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

# %%
df1.insert(21,'screen_size',screen_size)

# %%
df1['screen_size'].value_counts()
# Out:
# screen_size
# 6.50    119
# 6.67     97
# 6.70     93
# 6.60     91
# 6.43     43
# 6.40     43
# 6.58     40
# 6.80     35
# 6.78     33
# 6.10     31
# 6.44     31
# 6.51     29
# 6.52     27
# 6.56     25
# 6.53     25
# 6.55     25
# 6.62     18
# 6.73     18
# 6.00     11
# 6.59     10
# 6.20      9
# 6.71      9
# 6.82      7
# 4.70      5
# 5.00      5
# 6.30      5
# 6.90      5
# 6.35      4
# 6.22      4
# 8.03      4
# 5.40      4
# 6.28      3
# 6.76      3
# 6.95      3
# 6.57      3
# 5.50      3
# 7.10      3
# 7.60      3
# 6.47      3
# 6.83      2
# 6.39      2
# 6.74      2
# 6.18      2
# 6.06      2
# 6.49      2
# 5.90      2
# 7.80      2
# 5.45      2
# 6.81      2
# 6.72      2
# 5.70      1
# 5.84      1
# 8.01      1
# 6.14      1
# 4.00      1
# 5.30      1
# 7.20      1
# 6.38      1
# 6.34      1
# 6.09      1
# 8.00      1
# 5.20      1
# 6.75      1
# 7.00      1
# 6.91      1
# 7.40      1
# 6.68      1
# 6.54      1
# 6.92      1
# 3.54      1
# 6.64      1
# 6.66      1
# 8.02      1
# 5.42      1
# 6.36      1
# 4.50      1
# 7.92      1
# 6.26      1
# 5.86      1
# Name: count, dtype: int64

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x: 60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(23,'refresh_rate',refresh_rate)

# %%
df1['camera']
# Out:
# 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 5       50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 6            12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 7       200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 8            50 MP + 50 MP Dual Rear & 16 MP Front Camera
# 9       50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 10           108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 11             50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 12      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 13      50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 14                  200 MP Quad Rear & 12 MP Front Camera
# 15           12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 16             13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 17      50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 18      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 19             50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 20      50 MP + 12 MP + 2 MP Triple Rear & 16 MP Front...
# 21      64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 22      64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 23      48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 24      64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 25      12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 26      64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 27      48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 28      64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 29      50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 30           108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 31      108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 32      64 MP + 13 MP + 2 MP Triple Rear & 50 MP Front...
# 33           12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 34                  108 MP Quad Rear & 32 MP Front Camera
# 35      12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 36      108 MP + 13 MP + 2 MP Triple Rear & 16 MP Fron...
# 37                  108 MP Quad Rear & 40 MP Front Camera
# 38                  108 MP Quad Rear & 32 MP Front Camera
# 39            64 MP + 2 MP Dual Rear & 32 MP Front Camera
# 40      108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 41      108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 42      108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 43      108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 44      50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 45                    50 MP Quad Rear & 8 MP Front Camera
# 46                   50 MP Quad Rear & 13 MP Front Camera
# 47           50 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 48             13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 49                  108 MP Quad Rear & 32 MP Front Camera
# 50      50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 51      64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 52                         13 MP Rear & 8 MP Front Camera
# 53      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 54            50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 55      50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 56           12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 57                   64 MP Quad Rear & 13 MP Front Camera
# 58      50 MP + 12 MP + 10 MP Triple Rear & 12 MP Fron...
# 59      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 60      108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 61      64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 62                    50 MP Quad Rear & 8 MP Front Camera
# 63             50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 64            50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 65      50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 66      50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front...
# 67      200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 68      50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 69                         Foldable Display, Dual Display
# 70                          8 MP Rear & 5 MP Front Camera
# 71      64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# 72             50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 73      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 74      48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 75                    13 MP Dual Rear & 5 MP Front Camera
# 76      12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 77      64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 78                   48 MP Quad Rear & 13 MP Front Camera
# 79                         13 MP Rear & 5 MP Front Camera
# 80      108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 81      50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 82      48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 83      50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 84             50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 85      50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 86                    50 MP Quad Rear & 8 MP Front Camera
# 87             48 MP + 2 MP Dual Rear & 8 MP Front Camera
# 88                   50 MP Quad Rear & 13 MP Front Camera
# 89                  108 MP Quad Rear & 32 MP Front Camera
# 90             13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 91      64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 92      50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 93                 50.3 MP Quad Rear & 32 MP Front Camera
# 94           50 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 95      50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 96             50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 97      50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front...
# 98                   50 MP Quad Rear & 16 MP Front Camera
# 99      50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 100     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 101                 108 MP Quad Rear & 32 MP Front Camera
# 102     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 103          50 MP + 0.3 MP Dual Rear & 8 MP Front Camera
# 104                  48 MP Quad Rear & 16 MP Front Camera
# 105     50.3 MP + 50 MP + 50 MP Triple Rear & 32 MP Fr...
# 106     108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 107     50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 108     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 109     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 110     64 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 111          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 112     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 113                  64 MP Quad Rear & 32 MP Front Camera
# 114                    8 MP Dual Rear & 5 MP Front Camera
# 115     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 116                 108 MP Quad Rear & 32 MP Front Camera
# 117     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 118     50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 119     50 MP + 12 MP + 10 MP Triple Rear & 12 MP Fron...
# 120     50 MP + 50 MP + 2 MP Triple Rear & 60 MP Front...
# 121     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 122         12.2 MP + 12 MP Dual Rear & 8 MP Front Camera
# 123     108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 124                   50 MP Quad Rear & 8 MP Front Camera
# 125     64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# 126     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 127     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 128                  48 MP Quad Rear & 13 MP Front Camera
# 129         12.2 MP + 12 MP Dual Rear & 8 MP Front Camera
# 130            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 131                  48 MP Quad Rear & 16 MP Front Camera
# 132     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 133          50 MP + 50 MP Dual Rear & 16 MP Front Camera
# 134     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 135     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 136          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 137     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 138     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 139     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 140     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 141           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 142           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 143                         5 MP Rear & 2 MP Front Camera
# 144     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 145            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 146     48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 147                  64 MP Quad Rear & 32 MP Front Camera
# 148            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 149          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 150     48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 151     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 152     50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 153          108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 154     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 156                         8 MP Rear & 5 MP Front Camera
# 157     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 158     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 159     50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 160     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 161           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 162     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 163                  64 MP Quad Rear & 32 MP Front Camera
# 164     50 MP + 12 MP + 12 MP Triple Rear & 32 MP Fron...
# 165     50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 166                  64 MP Quad Rear & 13 MP Front Camera
# 167           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 168     48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 169                   50 MP Dual Rear & 8 MP Front Camera
# 170     8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 171                 108 MP Quad Rear & 32 MP Front Camera
# 172     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 173     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 174                        12 MP Rear & 7 MP Front Camera
# 175            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 176                  64 MP Quad Rear & 13 MP Front Camera
# 177     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 178     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 179     64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 180     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 181     200 MP + 13 MP + 2 MP Triple Rear & 32 MP Fron...
# 182                   13 MP Dual Rear & 5 MP Front Camera
# 183     50 MP + 50 MP + 12 MP Triple Rear & 60 MP Fron...
# 184     50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 185          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 186     50 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 187     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 188                        13 MP Rear & 8 MP Front Camera
# 189     13 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 190            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 191                         8 MP Rear & 2 MP Front Camera
# 192     64 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 193                200 MP Penta Rear & 32 MP Front Camera
# 194     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 195     50 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front...
# 196     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 197     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 198     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 199            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 200            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 201                   50 MP Quad Rear & 8 MP Front Camera
# 202     200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 203                 108 MP Quad Rear & 32 MP Front Camera
# 204     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 205            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 206          50 MP + 50 MP Dual Rear & 16 MP Front Camera
# 207     50 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 208                   50 MP Dual Rear & 8 MP Front Camera
# 209     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 210     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 211     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 212     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 213     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 214          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 215     64 MP + 5 MP + 2 MP Triple Rear & 16 MP Front ...
# 216     50 MP + 48 MP + 12 MP Triple Rear & 10.8 MP Fr...
# 217     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 218     108 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 M...
# 219            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 220     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 221     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 222     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 223     50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 224                  50 MP Quad Rear & 13 MP Front Camera
# 225                         8 MP Rear & 5 MP Front Camera
# 226     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 227     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 228     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 229     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 230     50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front...
# 231     50 MP + 50 MP + 13 MP Triple Rear & 16 MP Fron...
# 232            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 233            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 234            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 235     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 236     50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 237            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 238     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 239     50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 240     200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 241            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 242                 108 MP Quad Rear & 32 MP Front Camera
# 243     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 244        50 MP + 12 MP Dual Rear & 10.8 MP Front Camera
# 245           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 246     64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 247          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 248           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 249     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 250     50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 251     50 MP + 50 MP + 13 MP Triple Rear & 32 MP Fron...
# 252     108 MP + 13 MP + 2 MP Triple Rear & 60 MP Fron...
# 253     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 254     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 255          108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 256     12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 257     50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 258            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 259     50 MP + 5 MP + 2 MP Triple Rear & 16 MP Front ...
# 260            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 261         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 262     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 263            12 MP + 5 MP Dual Rear & 7 MP Front Camera
# 264                  64 MP Quad Rear & 32 MP Front Camera
# 265         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 266     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 267     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 268                 108 MP Quad Rear & 16 MP Front Camera
# 269     50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 270                  64 MP Quad Rear & 20 MP Front Camera
# 272     50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Fr...
# 273          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 274            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 275     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 276     50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 277          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 278     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 279     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 280     50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 281     50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 282          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 283     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 284     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 285                   50 MP Quad Rear & 8 MP Front Camera
# 286     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 287     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 288        108 MP + 2 MP Triple Rear & 16 MP Front Camera
# 289                   50 MP Dual Rear & 8 MP Front Camera
# 290     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 291     50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 292           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 293                  64 MP Quad Rear & 13 MP Front Camera
# 294                         8 MP Rear & 5 MP Front Camera
# 295                   50 MP Quad Rear & 8 MP Front Camera
# 296     200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 297     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 298     50 MP + 12 MP + 10 MP Triple Rear & 32 MP Fron...
# 299                        13 MP Rear & 5 MP Front Camera
# 300                         8 MP Rear & 5 MP Front Camera
# 301     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 302                         8 MP Rear & 5 MP Front Camera
# 303     50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 304            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 305     64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 306          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 308     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 309                   50 MP Quad Rear & 8 MP Front Camera
# 310     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 311     50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front...
# 312                  64 MP Quad Rear & 32 MP Front Camera
# 313                 108 MP Quad Rear & 40 MP Front Camera
# 314     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 315     8 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front ...
# 316     50 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# 317            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 318     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 319     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 320     50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front...
# 321     50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 323          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 324                  48 MP Quad Rear & 13 MP Front Camera
# 325                   13 MP Dual Rear & 8 MP Front Camera
# 326           50 MP + 12 MP Dual Rear & 8 MP Front Camera
# 327                  64 MP Quad Rear & 16 MP Front Camera
# 328                 108 MP Quad Rear & 40 MP Front Camera
# 329                   13 MP Dual Rear & 8 MP Front Camera
# 330            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 331     64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 332     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 333                 108 MP Quad Rear & 32 MP Front Camera
# 334     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 335     64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 336         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 337                         8 MP Rear & 5 MP Front Camera
# 338     108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 339                  48 MP Quad Rear & 16 MP Front Camera
# 340                 108 MP Quad Rear & 16 MP Front Camera
# 341            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 342     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 343            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 344     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 345     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 346          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 347     50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 348     50.3 MP + 50 MP + 12 MP Triple Rear & 32 MP Fr...
# 349           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 350                  50 MP Quad Rear & 16 MP Front Camera
# 351                        13 MP Rear & 5 MP Front Camera
# 352                        13 MP Rear & 8 MP Front Camera
# 353            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 354     54 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 355                         8 MP Rear & 5 MP Front Camera
# 356            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 357                   50 MP Dual Rear & 8 MP Front Camera
# 358                        13 MP Rear & 5 MP Front Camera
# 359     64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 360     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 361     200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 362     48 MP + 13 MP + 13 MP Triple Rear & 16 MP Fron...
# 363          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 364                 200 MP Quad Rear & 60 MP Front Camera
# 365           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 366     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 367                   13 MP Dual Rear & 8 MP Front Camera
# 368     12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 369           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 370     12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...
# 371      64 MP Quad Rear & 44 MP + 8 MP Dual Front Camera
# 372                  64 MP Quad Rear & 20 MP Front Camera
# 373     12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 374     16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual...
# 375     16 MP + 12 MP + 12 MP Triple Rear & 10 MP + 8 ...
# 377     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 378     64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 379     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 380     64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 381                  64 MP Quad Rear & 32 MP Front Camera
# 382                         8 MP Rear & 5 MP Front Camera
# 383     13 MP + Depth Sensor + Ultra Wide Triple Rear ...
# 384                   13 MP Dual Rear & 8 MP Front Camera
# 385     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 386     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 387     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 388     50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 389     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 390     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 391     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 392           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 393                  64 MP Quad Rear & 20 MP Front Camera
# 394     64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front...
# 395     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 396                  48 MP Quad Rear & 16 MP Front Camera
# 397     50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 398           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 399           8 MP + 0.3 MP Dual Rear & 8 MP Front Camera
# 401     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 402     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 403                    8 MP Dual Rear & 5 MP Front Camera
# 404     200 MP + 12 MP + 12 MP Triple Rear & 10 MP Fro...
# 405     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 406           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 407                  50 MP Quad Rear & 32 MP Front Camera
# 408                  64 MP Quad Rear & 32 MP Front Camera
# 409     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 410     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 411            48 MP + 2 MP Dual Rear & 8 MP Front Camera
# 412     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 413            48 MP + 2 MP Dual Rear & 5 MP Front Camera
# 414     13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 415     48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 416     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 417      64 MP Quad Rear & 32 MP + 8 MP Dual Front Camera
# 418                        13 MP Rear & 5 MP Front Camera
# 419     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 420     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 421     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 422     200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 423     50 MP + 48 MP + 48 MP Triple Rear & 32 MP Fron...
# 424     54 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 425     50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front...
# 426     108 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 M...
# 427     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 428     108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 429                 108 MP Quad Rear & 32 MP Front Camera
# 430                  48 MP Quad Rear & 13 MP Front Camera
# 431                      13 MP Rear & 2.1 MP Front Camera
# 432                  64 MP Quad Rear & 20 MP Front Camera
# 433     64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 434     64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 435                  48 MP Quad Rear & 16 MP Front Camera
# 436                        13 MP Rear & 5 MP Front Camera
# 437            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 438                 108 MP Quad Rear & 16 MP Front Camera
# 439                        12 MP Rear & 7 MP Front Camera
# 440                  64 MP Quad Rear & 32 MP Front Camera
# 441                  48 MP Quad Rear & 20 MP Front Camera
# 442                        13 MP Rear & 5 MP Front Camera
# 443                  64 MP Quad Rear & 20 MP Front Camera
# 444     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 445     50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 446     200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 447                    8 MP Dual Rear & 5 MP Front Camera
# 448     50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 449     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 450          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 451     50 MP + 12 MP + 12 MP Triple Rear & 32 MP Fron...
# 452     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 453     50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 M...
# 454            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 455     50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 456          50 MP + 12 MP Dual Rear & 12 MP Front Camera
# 457     13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 458     48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 459                 48 MP Triple Rear & 8 MP Front Camera
# 460                   50 MP Quad Rear & 8 MP Front Camera
# 461                  48 MP Quad Rear & 13 MP Front Camera
# 462             108 MP + 20 MP + 12 MP Triple Rear Camera
# 463           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 464        64 MP + 50 MP Triple Rear & 16 MP Front Camera
# 465     50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 466            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 467                   13 MP Dual Rear & 8 MP Front Camera
# 468     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 469     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 470     64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 471                         8 MP Rear & 5 MP Front Camera
# 472     108 MP + 8 MP + 8 MP Triple Rear & 16 MP Front...
# 474                  64 MP Quad Rear & 20 MP Front Camera
# 475     64 MP + 12 MP + 5 MP Triple Rear & 10 MP Front...
# 476           12 MP + 5 MP Dual Rear & 20 MP Front Camera
# 477                         5 MP Rear & 2 MP Front Camera
# 478            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 479                        13 MP Rear & 5 MP Front Camera
# 480                    8 MP Dual Rear & 5 MP Front Camera
# 481                       2 MP Rear & 0.3 MP Front Camera
# 482     50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 483     50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 484                  64 MP Quad Rear & 32 MP Front Camera
# 485     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 487     12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...
# 488     13 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 489                  12 MP Quad Rear & 12 MP Front Camera
# 490                   50 MP Dual Rear & 8 MP Front Camera
# 491     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 492            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 493     64 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 494     16 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 495     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 496     48 MP + 8 MP + 5 MP Triple Rear & 8 MP Front C...
# 497     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 498     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 499            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 500     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 501     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 502     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 503     50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 504          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 505          20 MP + 16 MP Dual Rear & 16 MP Front Camera
# 506                      12.2 MP Rear & 8 MP Front Camera
# 507           8 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 508     54 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 509     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 510            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 511                  64 MP Quad Rear & 20 MP Front Camera
# 512     64 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 513     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 514     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 515         16 MP + 12.2 MP Dual Rear & 8 MP Front Camera
# 516     108 MP + 50 MP + 48 MP Triple Rear & 32 MP Fro...
# 517     200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 518     50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 519     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 520     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 521     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 522            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 523     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 524                         8 MP Rear & 5 MP Front Camera
# 525     108 MP + 13 MP + 2 MP Triple Rear & 16 MP Fron...
# 526     50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 527     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 528     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 529     50 MP + 5 MP + 2 MP Triple Rear & 16 MP Front ...
# 530     64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 531                  48 MP Quad Rear & 16 MP Front Camera
# 534     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 535     50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Fr...
# 536     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 537     50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 538     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 539            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 540     64 MP + 64 MP + 64 MP Triple Rear & 16 MP Fron...
# 541     50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 542     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 543                 108 MP Quad Rear & 16 MP Front Camera
# 544     50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 545          64 MP + 13 MP Dual Rear & 16 MP Front Camera
# 546     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 547                  48 MP Quad Rear & 16 MP Front Camera
# 548     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 549     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 550                 200 MP Quad Rear & 32 MP Front Camera
# 552     48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 553                 108 MP Quad Rear & 16 MP Front Camera
# 554     48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 555                  64 MP Quad Rear & 16 MP Front Camera
# 556     64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 557     48 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 558     16 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 559     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 560                  50 MP Quad Rear & 16 MP Front Camera
# 561     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 562                        13 MP Rear & 5 MP Front Camera
# 563     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 564     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 565     64 MP + 13 MP + 5 MP Triple Rear & 24 MP Front...
# 566     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 567                  48 MP Quad Rear & 13 MP Front Camera
# 568     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 569     12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570     64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 571                  64 MP Quad Rear & 32 MP Front Camera
# 572                  64 MP Quad Rear & 32 MP Front Camera
# 574                        13 MP Rear & 5 MP Front Camera
# 576            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 577            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 578     50 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 579     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 580     50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 581                   50 MP Dual Rear & 8 MP Front Camera
# 583     50 MP + 50 MP + 12 MP Triple Rear & 60 MP Fron...
# 584     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 585     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 586     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 587                   50 MP Quad Rear & 8 MP Front Camera
# 588                        13 MP Rear & 5 MP Front Camera
# 589            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 590     48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 591     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 592     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 593     64 MP + 12 MP + 2 MP Triple Rear & 16 MP Front...
# 594     50 MP + 50 MP + 16 MP Triple Rear & 16 MP Fron...
# 595                         8 MP Rear & 5 MP Front Camera
# 596            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 597                        13 MP Rear & 8 MP Front Camera
# 598                  48 MP Quad Rear & 13 MP Front Camera
# 599     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 600     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 601     48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 602     64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 603                  64 MP Quad Rear & 32 MP Front Camera
# 604     48 MP + 16 MP + 2 MP Triple Rear & 16 MP Front...
# 605                 108 MP Quad Rear & 40 MP Front Camera
# 606     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607                        13 MP Rear & 7 MP Front Camera
# 609           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 610            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 612     48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 613     64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 614     108 MP + 13 MP + 2 MP Triple Rear & 32 MP Fron...
# 615     64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 616     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 617     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 618     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 619                 108 MP Quad Rear & 16 MP Front Camera
# 620                  64 MP Quad Rear & 16 MP Front Camera
# 621     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 622     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 623     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 624     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 625     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 626     64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 628     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 629                   12 MP Quad Rear & 8 MP Front Camera
# 630     108 MP + 16 MP + 8 MP Triple Rear & 25 MP Fron...
# 631     64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 632                   48 MP Quad Rear & 8 MP Front Camera
# 633     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 634     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 635                         8 MP Rear & 5 MP Front Camera
# 636          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 637     50 MP + 13 MP + 12 MP Triple Rear & 16 MP Fron...
# 638     64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 639     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 641                 108 MP Quad Rear & 40 MP Front Camera
# 642     64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 643     108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 644            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 646     64 MP + 12 MP + 5 MP Triple Rear & 10 MP Front...
# 648     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 649     50 MP + 20 MP + 12 MP Triple Rear & 13 MP Dual...
# 650            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 651     50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 652     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 653     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 654     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 655            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 656                        12 MP Rear & 7 MP Front Camera
# 658     8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 659     64 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 660            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 661     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 662     64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 663     50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 664     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 666          8 MP + 0.08 MP Dual Rear & 5 MP Front Camera
# 667           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 668            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 669             50 MP Quad Rear & 13 MP Dual Front Camera
# 670          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 671                    8 MP Dual Rear & 5 MP Front Camera
# 672     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 673                   48 MP Quad Rear & 8 MP Front Camera
# 674         64 MP + 2 MP Triple Rear & 16 MP Front Camera
# 675     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 676     48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 677                  48 MP Quad Rear & 13 MP Front Camera
# 678                 108 MP Quad Rear & 16 MP Front Camera
# 679     64 MP + 13 MP + 5 MP Triple Rear & 20 MP Front...
# 680     48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...
# 681                  64 MP Quad Rear & 16 MP Front Camera
# 682     64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 683     12 MP + 12 MP + 12 MP Triple Rear & 32 MP Fron...
# 684                  12 MP Quad Rear & 10 MP Front Camera
# 686     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 687     50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 688            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 689                         8 MP Rear & 5 MP Front Camera
# 690          8 MP + 0.08 MP Dual Rear & 5 MP Front Camera
# 691            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 692     108 MP + 13 MP + 2 MP Triple Rear & 32 MP Fron...
# 693            48 MP + 2 MP Dual Rear & 8 MP Front Camera
# 694     48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...
# 695                 108 MP Quad Rear & 16 MP Front Camera
# 696                        13 MP Rear & 5 MP Front Camera
# 697     8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 698     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 700     64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front...
# 701     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 702     108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 703     50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 704     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 705     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 706     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 707     48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 708                  48 MP Quad Rear & 16 MP Front Camera
# 709     64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 710                  64 MP Quad Rear & 16 MP Front Camera
# 711                       16 MP Rear & 13 MP Front Camera
# 712                   13 MP Quad Rear & 8 MP Front Camera
# 713      48 MP Quad Rear & 16 MP + 2 MP Dual Front Camera
# 714     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 715     48 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 716                  12 MP Quad Rear & 10 MP Front Camera
# 717     13 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 718                  48 MP Quad Rear & 32 MP Front Camera
# 719     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 720     64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 721     50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 722          64 MP + 13 MP Dual Rear & 32 MP Front Camera
# 723     108 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 724     64 MP + 50 MP + 13 MP Triple Rear & 13 MP Fron...
# 725     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 726     50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 727     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 728          50 MP + 13 MP Dual Rear & 13 MP Front Camera
# 729     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 730            16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 731            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 732                  50 MP Quad Rear & 32 MP Front Camera
# 733                   50 MP Quad Rear & 8 MP Front Camera
# 734                  50 MP Quad Rear & 32 MP Front Camera
# 735           5 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 736                  50 MP Quad Rear & 13 MP Front Camera
# 737     48 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 738                         5 MP Rear & 5 MP Front Camera
# 739     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 740                  50 MP Quad Rear & 32 MP Front Camera
# 741      64 MP Quad Rear & 16 MP + 8 MP Dual Front Camera
# 742                  50 MP Quad Rear & 32 MP Front Camera
# 743     48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 744     8 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front ...
# 745     64 MP + 8 MP + 2 MP Triple Rear & 44 MP + 8 MP...
# 746     108 MP + 13 MP + 5 MP Triple Rear & 20 MP Fron...
# 747      48 MP Quad Rear & 32 MP + 8 MP Dual Front Camera
# 749     64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 750     16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 751                  64 MP Quad Rear & 32 MP Front Camera
# 752                  64 MP Quad Rear & 16 MP Front Camera
# 753     13 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 755           12 MP + 5 MP Dual Rear & 20 MP Front Camera
# 756                    8 MP Dual Rear & 5 MP Front Camera
# 758                       20 MP Rear & 13 MP Front Camera
# 759     50 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 760     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 761     200 MP + 50 MP + 8 MP Triple Rear & 50 MP Fron...
# 762                     12 MP Rear & 10.8 MP Front Camera
# 763                   50 MP Dual Rear & 8 MP Front Camera
# 764     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 765         50 MP + 8 MP Dual Rear & 10.1 MP Front Camera
# 766           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 767     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 768     50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 769                  50 MP Quad Rear & 16 MP Front Camera
# 770     50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 771            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 772                  64 MP Quad Rear & 16 MP Front Camera
# 773            48 MP + 2 MP Dual Rear & 5 MP Front Camera
# 774     50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 775     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 776     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 777     50 MP + 50 MP + 13 MP Triple Rear & 32 MP Fron...
# 778            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 779            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 780                        13 MP Rear & 5 MP Front Camera
# 781     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 782     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 783     64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 784                  48 MP Quad Rear & 13 MP Front Camera
# 785     50 MP + 50 MP + 50 MP Triple Rear & 20 MP Fron...
# 786                         8 MP Rear & 5 MP Front Camera
# 787     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 788     13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 789                  48 MP Quad Rear & 13 MP Front Camera
# 790     108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 791     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 792     13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 793     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 794                    8 MP Dual Rear & 5 MP Front Camera
# 795                   48 MP Quad Rear & 8 MP Front Camera
# 796     64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 797                  48 MP Quad Rear & 16 MP Front Camera
# 798                  64 MP Quad Rear & 10 MP Front Camera
# 799      64 MP Quad Rear & 16 MP + 8 MP Dual Front Camera
# 800             50 MP Quad Rear & 32 MP Dual Front Camera
# 801            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 802     48 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 803           13 MP + 2 MP Dual Rear & 20 MP Front Camera
# 804           16 MP + 5 MP Dual Rear & 25 MP Front Camera
# 805           12 MP + 12 MP Dual Rear & 8 MP Front Camera
# 806     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 807            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 808            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 809     47.2 MP + 1.9 MP Dual Rear & 12.6 MP Front Camera
# 810     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 811     50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 812     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 813          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 814     48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 815           64 MP + 2 MP Dual Rear & 16 MP Front Camera
# 816     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 818            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 819           48 MP + 2 MP Dual Rear & 16 MP Front Camera
# 820         48 MP + 2 MP Triple Rear & 32 MP Front Camera
# 821                         8 MP Rear & 5 MP Front Camera
# 822     108 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 823            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 824         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 825                  64 MP Quad Rear & 32 MP Front Camera
# 826     64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 827     50 MP + 12 MP + 12 MP Triple Rear & 32 MP Fron...
# 828                  64 MP Quad Rear & 32 MP Front Camera
# 829         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 830     48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 831     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 832            50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 833                 108 MP Quad Rear & 16 MP Front Camera
# 834     50 MP + 3 MP + 2 MP Triple Rear & 8 MP Front C...
# 836            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 837     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 838                        13 MP Rear & 5 MP Front Camera
# 839                  48 MP Quad Rear & 16 MP Front Camera
# 840          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 841          50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 842     50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 843     50 MP + 13 MP + 5 MP Triple Rear & 32 MP Front...
# 844                         5 MP Rear & 2 MP Front Camera
# 845     64 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...
# 847     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 848     108 MP + 8 MP + 5 MP Triple Rear & 20 MP Front...
# 849          64 MP + 16 MP Dual Rear & 20 MP Front Camera
# 850                  64 MP Quad Rear & 32 MP Front Camera
# 851     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 853     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 854                        13 MP Rear & 5 MP Front Camera
# 855                  64 MP Quad Rear & 16 MP Front Camera
# 856                         8 MP Rear & 5 MP Front Camera
# 858                  64 MP Quad Rear & 32 MP Front Camera
# 859     12 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 860     12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...
# 861                        13 MP Rear & 5 MP Front Camera
# 862                  48 MP Quad Rear & 16 MP Front Camera
# 863     16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 864     16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 865                  48 MP Quad Rear & 13 MP Front Camera
# 866            12 MP + 2 MP Dual Rear & 8 MP Front Camera
# 867     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 868                      12.2 MP Rear & 8 MP Front Camera
# 869           16 MP + 5 MP Dual Rear & 25 MP Front Camera
# 870     16 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 871           13 MP + 2 MP Dual Rear & 16 MP Front Camera
# 872                        13 MP Rear & 5 MP Front Camera
# 874     108 MP + 20 MP + 16 MP Triple Rear & 32 MP Fro...
# 875          50 MP + 2 MP Triple Rear & 5 MP Front Camera
# 876     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 877     64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 878     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 879          50 MP + 13 MP Dual Rear & 16 MP Front Camera
# 880            16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 883            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 884     50 MP + 8 MP + 2 MP Triple Rear & 60 MP Front ...
# 885                   50 MP Quad Rear & 8 MP Front Camera
# 886     48 MP + 12 MP + 5 MP Triple Rear & 16 MP Front...
# 887     108 MP + 13 MP + 2 MP Triple Rear & 16 MP Fron...
# 888     50 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 889     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 890     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 891     48 MP + 13 MP + 13 MP Triple Rear & 16 MP Fron...
# 892     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 893           48 MP + 2 MP Dual Rear & 16 MP Front Camera
# 894     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 895     48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 896      50 MP Quad Rear & 48 MP + 8 MP Dual Front Camera
# 897            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 898     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 899     12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...
# 900     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 901                   48 MP Quad Rear & 8 MP Front Camera
# 902     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 903     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 904                 108 MP Quad Rear & 16 MP Front Camera
# 905                  64 MP Quad Rear & 16 MP Front Camera
# 906     48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 907                         5 MP Rear & 2 MP Front Camera
# 908                 108 MP Quad Rear & 40 MP Front Camera
# 909                  64 MP Quad Rear & 32 MP Front Camera
# 910                  48 MP Quad Rear & 13 MP Front Camera
# 911                   48 MP Quad Rear & 8 MP Front Camera
# 912     13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 913          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 915     13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 916                  48 MP Quad Rear & 16 MP Front Camera
# 918            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 919      64 MP Quad Rear & 32 MP + 8 MP Dual Front Camera
# 920                  64 MP Quad Rear & 10 MP Front Camera
# 921     48 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 922                  64 MP Quad Rear & 20 MP Front Camera
# 923            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 924                       13 MP Rear & 16 MP Front Camera
# 926                       13 MP Rear & 13 MP Front Camera
# 928          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 929     50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 931          13 MP + 2 MP Triple Rear & 8 MP Front Camera
# 933     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 934     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 935            16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 936           8 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 937                   13 MP Dual Rear & 8 MP Front Camera
# 938                   13 MP Dual Rear & 8 MP Front Camera
# 939                  50 MP Quad Rear & 16 MP Front Camera
# 940     50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 941     50 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...
# 942                        13 MP Rear & 5 MP Front Camera
# 943     50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 944          50 MP + 12 MP Dual Rear & 16 MP Front Camera
# 945     200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 946     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 947        50 MP + 50 MP Triple Rear & 16 MP Front Camera
# 948     64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 949            48 MP + 2 MP Dual Rear & 5 MP Front Camera
# 950         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 951     64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 952     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 953     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 954                  50 MP Quad Rear & 16 MP Front Camera
# 955     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 956                   13 MP Dual Rear & 8 MP Front Camera
# 957     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 958         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 959     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 960     64 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 961     12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 962     64 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 963            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 964                 200 MP Quad Rear & 16 MP Front Camera
# 965            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 966                  64 MP Quad Rear & 16 MP Front Camera
# 967     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 968                 108 MP Quad Rear & 32 MP Front Camera
# 969     13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 970     50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 971     48 MP + 13 MP + 13 MP Triple Rear & 16 MP Fron...
# 972                         8 MP Rear & 5 MP Front Camera
# 973                  48 MP Quad Rear & 13 MP Front Camera
# 974     64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 975         16 MP + 12.2 MP Dual Rear & 8 MP Front Camera
# 976                   48 MP Quad Rear & 8 MP Front Camera
# 977     64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 978                  48 MP Quad Rear & 13 MP Front Camera
# 979                        13 MP Rear & 5 MP Front Camera
# 980     48 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 981     13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 982     48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 983           8 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 984            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 985                 108 MP Quad Rear & 20 MP Front Camera
# 986           13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 987     64 MP + 16 MP + 2 MP Triple Rear & 16 MP Front...
# 989     48 MP + 12.2 MP + 12.2 MP Triple Rear & 16 MP ...
# 990             40 MP Quad Rear & 32 MP Dual Front Camera
# 991     13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 992            13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 993                                48 MP Quad Rear Camera
# 994     24 MP + 10 MP + 5 MP Triple Rear & 24 MP Front...
# 995     24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front ...
# 996                        13 MP Rear & 5 MP Front Camera
# 997     50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 998                   13 MP Dual Rear & 8 MP Front Camera
# 999                   50 MP Quad Rear & 8 MP Front Camera
# 1001           13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 1002    108 MP + 64 MP + 16 MP Triple Rear & 32 MP Fro...
# 1003                   8 MP Dual Rear & 5 MP Front Camera
# 1004    50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 1005                      20 MP Rear & 13 MP Front Camera
# 1006    16 MP + 13 MP + 13 MP Triple Rear & 8 MP Front...
# 1007    50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 1008    50 MP + 13 MP + 2 MP Triple Rear & 32 MP + 16 ...
# 1009    64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...
# 1010                        8 MP Rear & 5 MP Front Camera
# 1011    50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...
# 1012                                     2 MP Rear Camera
# 1013    50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...
# 1014    50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
# 1015    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, dtype: object

# %%
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_ext)

# %%
def camera_ext(text):
    if 'Quad' in text:
        return 4
    elif 'Triple' in text:
        return 3
    elif 'Dual' in text:
        return 3
    elif 'Missing' in text:
        return 'Missing'
    else:
        return 1

# %%
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating
# 0      2    oneplus              OnePlus 11 5G  54999    89.0  \
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5G  has_nfc
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True  \
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor  ... ram_capacity
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...         12.0  \
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...          6.0
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...          4.0
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...          6.0
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...          6.0
#
#                                              display  screen_size
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70  \
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#      resolution  refresh_rate
# 0  1440 x 3216            120  \
# 1  1080 x 2412            120
# 2  1080 x 2408             90
# 3  1080 x 2400            120
# 4  1080 x 2412            120
#
#                                               camera  num_rear_cameras
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                 3  \
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                 3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                 3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                 3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                 3
#
#                                card           os  ram memory
# 0         Memory Card Not Supported  Android v13         NaN
# 1   Memory Card (Hybrid), upto 1 TB  Android v12         NaN
# 2  Memory Card Supported, upto 1 TB  Android v13         NaN
# 3   Memory Card (Hybrid), upto 1 TB  Android v12         NaN
# 4         Memory Card Not Supported  Android v13         NaN
#
# [5 rows x 29 columns]

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_ext)

# %%
df1.insert(26,'num_front_cameras',num_front_cameras)
